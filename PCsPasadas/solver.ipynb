# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('./graficas.png'))

# %% [markdown]
# ### Granularidad
# En la gráfica de Execution Time notamos que la curva desciende para valores de p menores a 256 (punto óptimo), es decir, el cómputo es mayor a la comunicación, lo cual implica una granularidad menor que 1 (Granularidad gruesa).
# Granularidad: (t_comm/t_comp)

# %% [markdown]
# ### Escalabilidad
# Se observa escalabilidad fuerte, ya que n es constante. Cuando n varía con p, entonces es weak scaling. La condicion de eficiencia constante es la misma que de speedup ideal
